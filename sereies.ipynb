# %% [markdown]
# ## PANDAS SERIES
# A series is a one-D labeled array capable of holding any data type.The axis labels are collectively called the index

# %% [markdown]
# ## Creating series
# It is created vertically,labels are indexes
# There are multiple ways :

# %%
import numpy as np
import pandas as pd

# %%
#how to create labels
l=['a','b','c']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
#creating series
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
pd.Series(my_list,index=l)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
