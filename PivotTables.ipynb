# %% [markdown]
# Use to Create a personalized table based on values , index and coloumns with value in aggfunc=

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)
df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    140     45   John  January      Q1
# 1  2023-01-02       B   West    826     35   Mary  January      Q1
# 2  2023-01-03       C  North    349     57    Bob  January      Q1
# 3  2023-01-04       D  South    218     32  Alice  January      Q1
# 4  2023-01-05       A   East    868     45   John  January      Q1
# 5  2023-01-06       B   West    906     12   Mary  January      Q1
# 6  2023-01-07       C  North    577     24    Bob  January      Q1
# 7  2023-01-08       D  South    242     58  Alice  January      Q1
# 8  2023-01-09       A   East    439     93   John  January      Q1
# 9  2023-01-10       B   West    562     76   Mary  January      Q1
# 10 2023-01-11       C  North    350     52    Bob  January      Q1
# 11 2023-01-12       D  South    872     81  Alice  January      Q1
# 12 2023-01-13       A   East    619     79   John  January      Q1
# ...

# %%
pd.pivot_table(df,values="Sales",index="Region",columns="Product",aggfunc="max")
#us region mei sales ki aggfunc= ki value aayegi
# Out:
# Product      A      B      C      D
# Region
# East     868.0    NaN    NaN    NaN
# North      NaN    NaN  918.0    NaN
# South      NaN    NaN    NaN  872.0
# West       NaN  906.0    NaN    NaN

# %%
#multiple values table 
#values must be numeric cause aggfunc only treat numeric values
pd.pivot_table(df,values=['Sales','Units'],index='Region',columns='Product',aggfunc='min')
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     140.0    NaN    NaN    NaN  45.0   NaN   NaN   NaN
# North      NaN    NaN  110.0    NaN   NaN   NaN  20.0   NaN
# South      NaN    NaN    NaN  179.0   NaN   NaN   NaN  10.0
# West       NaN  562.0    NaN    NaN   NaN  12.0   NaN   NaN

# %% [markdown]
# **CROSS TABS**

# %%
#based on counts how may times a coloumns value appear in that row 
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
